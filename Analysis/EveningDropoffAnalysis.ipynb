# %%
import pandas as pd
pd.set_option('display.mpl_style', 'default')
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
# Out:
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2885: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
eveningdrop = pd.read_json("eveningdropoffs.json", orient="index")

# %%
eveningdrop[2010.0]=(eveningdrop[2010.0]-eveningdrop[2010.0].mean())/eveningdrop[2010.0].std()
eveningdrop[2011.0]=(eveningdrop[2011.0]-eveningdrop[2011.0].mean())/eveningdrop[2011.0].std()
eveningdrop[2012.0]=(eveningdrop[2012.0]-eveningdrop[2012.0].mean())/eveningdrop[2012.0].std()
eveningdrop[2013.0]=(eveningdrop[2013.0]-eveningdrop[2013.0].mean())/eveningdrop[2013.0].std()

# %%
eveningdrop.dropna(inplace=True)

# %%
evening95 = eveningdrop[eveningdrop<eveningdrop.quantile(0.95)]
evening95.describe()
# Out:
#            2010.0      2011.0      2012.0      2013.0         2014.0  \
# count  182.000000  182.000000  182.000000  182.000000     182.000000
# mean    -0.198637   -0.200153   -0.199555   -0.199234   65839.313187
# std      0.387243    0.387935    0.388944    0.394765  167898.681664
# min     -0.337035   -0.343057   -0.345747   -0.350684       7.000000
# 25%     -0.331482   -0.337335   -0.340201   -0.344915    2626.500000
# 50%     -0.323828   -0.329511   -0.332040   -0.337169    6380.000000
# 75%     -0.273782   -0.275898   -0.276546   -0.278740   32402.000000
# max      2.124684    2.051910    2.075177    2.010116  992865.000000
#
#               2015.0
# count     182.000000
# mean    57961.368132
# std    146066.311685
# min        22.000000
# 25%      2603.750000
# 50%      6210.000000
# 75%     32732.250000
# max    881965.000000

# %%
eveningdeltas = evening95.pct_change(axis = 1)
eveningdeltas = eveningdeltas.drop(2010.0, axis = 1)
eveningdeltas.dropna()
eveningdeltas.describe(percentiles=[0.05, 0.1, 0.5, 0.85, 0.9, 0.95])
# Out:
#            2011.0      2012.0      2013.0        2014.0      2015.0
# count  181.000000  182.000000  182.000000  1.820000e+02  182.000000
# mean     0.041356    0.043340    0.017968 -1.984170e+05   -0.041455
# std      0.296096    0.374012    0.212913  1.633672e+06    0.187791
# min     -1.122990   -0.435514   -0.601678 -1.692710e+07   -0.315789
# 5%      -0.084701   -0.108163   -0.048281 -1.269955e+06   -0.193079
# 10%     -0.023379   -0.031621   -0.020324 -2.825336e+05   -0.163713
# 50%      0.017443    0.007851    0.014586 -1.243990e+04   -0.062055
# 85%      0.019438    0.010954    0.019608 -1.012793e+03    0.048002
# 90%      0.020429    0.014638    0.026063  4.445377e+05    0.081843
# 95%      0.066080    0.098917    0.061069  8.899260e+05    0.114861
# max      3.106575    4.106260    2.404785  2.775225e+06    2.142857

# %%
largechange = eveningdeltas[deltas>=eveningdeltas.quantile(0.95)]
largechange = largechange.dropna(how='all')
largechange.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cea19d370b5a> in <module>()
# ----> 1 largechange = eveningdeltas[deltas>=eveningdeltas.quantile(0.95)]
#       2 largechange = largechange.dropna(how='all')
#       3 largechange.describe()
#
# NameError: name 'deltas' is not defined

# %%
largechange = eveningdeltas[eveningdeltas>=eveningdeltas.quantile(0.95)]
largechange = largechange.dropna(how='all')
largechange.describe()
# Out:
#           2011.0     2012.0     2013.0        2014.0     2015.0
# count  10.000000  10.000000  10.000000  1.000000e+01  10.000000
# mean    0.791044   0.962105   0.449418  1.579185e+06   0.355996
# std     0.954108   1.320559   0.719023  6.820417e+05   0.629223
# min     0.066080   0.100778   0.061107  8.911669e+05   0.114961
# 25%     0.214175   0.178388   0.106671  1.095961e+06   0.132505
# 50%     0.445686   0.361217   0.151104  1.241865e+06   0.138753
# 75%     0.801810   0.931629   0.394893  2.112593e+06   0.210573
# max     3.106575   4.106260   2.404785  2.775225e+06   2.142857

# %%
eveningdeltas.to_csv('eveningdropoffs.csv')

# %%
largechange.to_csv('highchangeevening.csv')

# %%
largechange
# Out:
#                                                     2011.0    2012.0  \
# Airport                                           0.182414       NaN
# Arden Heights                                          NaN       NaN
# Astoria                                           0.189354       NaN
# Baisley Park                                           NaN       NaN
# Brooklyn Heights-Cobble Hill                      3.106575  1.026438
# Brownsville                                            NaN       NaN
# Cambria Heights                                        NaN       NaN
# Canarsie                                               NaN       NaN
# Carroll Gardens-Columbia Street-Red Hook               NaN  2.496705
# Central Harlem South                              0.901818  0.460633
# Chinatown                                              NaN       NaN
# DUMBO-Vinegar Hill-Downtown Brooklyn-Boerum Hill  0.501786  0.261801
# East Flatbush-Farragut                                 NaN       NaN
# ...

# %%
eveningdrop = pd.read_json("eveningdropoffs.json", orient="index")

# %%
eveningdrop[2010.0]=(eveningdrop[2010.0]-eveningdrop[2010.0].mean())/eveningdrop[2010.0].std()
eveningdrop[2011.0]=(eveningdrop[2011.0]-eveningdrop[2011.0].mean())/eveningdrop[2011.0].std()
eveningdrop[2012.0]=(eveningdrop[2012.0]-eveningdrop[2012.0].mean())/eveningdrop[2012.0].std()
eveningdrop[2013.0]=(eveningdrop[2013.0]-eveningdrop[2013.0].mean())/eveningdrop[2013.0].std()
eveningdrop[2014.0]=(eveningdrop[2014.0]-eveningdrop[2014.0].mean())/eveningdrop[2014.0].std()
eveningdrop[2015.0]=(eveningdrop[2015.0]-eveningdrop[2015.0].mean())/eveningdrop[2015.0].std()

# %%
eveningdrop.dropna(inplace=True)

# %%
evening95 = eveningdrop[eveningdrop<eveningdrop.quantile(0.95)]
evening95.describe()
# Out:
#            2010.0      2011.0      2012.0      2013.0      2014.0      2015.0
# count  182.000000  182.000000  182.000000  182.000000  182.000000  182.000000
# mean    -0.198637   -0.200153   -0.199555   -0.199234   -0.200060   -0.199564
# std      0.387243    0.387935    0.388944    0.394765    0.396109    0.400979
# min     -0.337035   -0.343057   -0.345747   -0.350684   -0.355373   -0.358618
# 25%     -0.331482   -0.337335   -0.340201   -0.344915   -0.349193   -0.351531
# 50%     -0.323828   -0.329511   -0.332040   -0.337169   -0.340338   -0.341631
# 75%     -0.273782   -0.275898   -0.276546   -0.278740   -0.278946   -0.268822
# max      2.124684    2.051910    2.075177    2.010116    1.986992    2.062481

# %%
eveningdeltas = evening95.pct_change(axis = 1)
eveningdeltas = eveningdeltas.drop(2010.0, axis = 1)
eveningdeltas.dropna()
eveningdeltas.describe(percentiles=[0.05, 0.1, 0.5, 0.85, 0.9, 0.95])
# Out:
#            2011.0      2012.0      2013.0      2014.0      2015.0
# count  181.000000  182.000000  182.000000  182.000000  182.000000
# mean     0.041356    0.043340    0.017968    0.007513    0.014246
# std      0.296096    0.374012    0.212913    0.306176    0.185862
# min     -1.122990   -0.435514   -0.601678   -2.520680   -0.938813
# 5%      -0.084701   -0.108163   -0.048281   -0.121351   -0.122409
# 10%     -0.023379   -0.031621   -0.020324   -0.019567   -0.034035
# 50%      0.017443    0.007851    0.014586    0.010357    0.006863
# 85%      0.019438    0.010954    0.019608    0.013329    0.010162
# 90%      0.020429    0.014638    0.026063    0.014480    0.018525
# 95%      0.066080    0.098917    0.061069    0.077769    0.103882
# max      3.106575    4.106260    2.404785    2.965089    1.586759

# %%
largechange = eveningdeltas[eveningdeltas>=eveningdeltas.quantile(0.95)]
largechange = largechange.dropna(how='all')
largechange.describe()
# Out:
#           2011.0     2012.0     2013.0     2014.0     2015.0
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.791044   0.962105   0.449418   0.546129   0.513641
# std     0.954108   1.320559   0.719023   0.859404   0.474662
# min     0.066080   0.100778   0.061107   0.078004   0.104285
# 25%     0.214175   0.178388   0.106671   0.195440   0.183073
# 50%     0.445686   0.361217   0.151104   0.289209   0.312258
# 75%     0.801810   0.931629   0.394893   0.360855   0.691379
# max     3.106575   4.106260   2.404785   2.965089   1.586759

# %%
largechange.to_csv('highchangeeveningwith20142015.csv')

# %%
eveningdrop = pd.read_json("eveningdropoffs.json", orient="index")

# %%
eveningdrop = eveningdrop.drop(2015.0, axis = 1)

# %%
eveningdrop = eveningdrop.drop(2014.0, axis = 1)

# %%
eveningdrop
# Out:
#                                                      2010.0     2011.0  \
# Airport                                               44351    28348.0
# Allerton-Pelham Gardens                                2428     2526.0
# Annadale-Huguenot-Prince's Bay-Eltingville              379      394.0
# Arden Heights                                           324      328.0
# Astoria                                              249822   280298.0
# Auburndale                                             2592     2996.0
# Baisley Park                                           6659     8078.0
# Bath Beach                                             4393     4581.0
# Battery Park City-Lower Manhattan                    820026   840062.0
# Bay Ridge                                             51203    53428.0
# Bayside-Bayside Hills                                  6478     6943.0
# Bedford                                               66508    82482.0
# ...

# %%
eveningdrop[2010.0]=(eveningdrop[2010.0]-eveningdrop[2010.0].mean())/eveningdrop[2010.0].std()
eveningdrop[2011.0]=(eveningdrop[2011.0]-eveningdrop[2011.0].mean())/eveningdrop[2011.0].std()
eveningdrop[2012.0]=(eveningdrop[2012.0]-eveningdrop[2012.0].mean())/eveningdrop[2012.0].std()
eveningdrop[2013.0]=(eveningdrop[2013.0]-eveningdrop[2013.0].mean())/eveningdrop[2013.0].std()

# %%
eveningdrop.dropna(inplace=True)

# %%
evening95 = eveningdrop[eveningdrop<eveningdrop.quantile(0.95)]
evening95.describe()
# Out:
#            2010.0      2011.0      2012.0      2013.0
# count  183.000000  183.000000  183.000000  183.000000
# mean    -0.199395   -0.200936   -0.200356   -0.200062
# std      0.386314    0.387012    0.388025    0.393839
# min     -0.337368   -0.343377   -0.346087   -0.350779
# 25%     -0.331500   -0.337413   -0.340235   -0.344933
# 50%     -0.323912   -0.329554   -0.332048   -0.337505
# 75%     -0.274415   -0.278121   -0.279501   -0.279562
# max      2.124684    2.051910    2.075177    2.010116

# %%
eveningdeltas = evening95.pct_change(axis = 1)
eveningdeltas = eveningdeltas.drop(2010.0, axis = 1)
eveningdeltas.dropna()
eveningdeltas.describe(percentiles=[0.05, 0.1, 0.5, 0.85, 0.9, 0.95])
# Out:
#            2011.0      2012.0      2013.0
# count  182.000000  183.000000  183.000000
# mean     0.041227    0.043147    0.017944
# std      0.295282    0.372992    0.212328
# min     -1.122990   -0.435514   -0.601678
# 5%      -0.083775   -0.106947   -0.048101
# 10%     -0.022600   -0.031041   -0.020281
# 50%      0.017459    0.007867    0.014578
# 85%      0.019432    0.010922    0.019581
# 90%      0.020425    0.014587    0.025787
# 95%      0.065983    0.097056    0.061031
# max      3.106575    4.106260    2.404785

# %%
largechange = eveningdeltas[eveningdeltas>=eveningdeltas.quantile(0.95)]
largechange = largechange.dropna(how='all')
largechange.describe()
# Out:
#           2011.0     2012.0     2013.0
# count  10.000000  10.000000  10.000000
# mean    0.791044   0.962105   0.449418
# std     0.954108   1.320559   0.719023
# min     0.066080   0.100778   0.061107
# 25%     0.214175   0.178388   0.106671
# 50%     0.445686   0.361217   0.151104
# 75%     0.801810   0.931629   0.394893
# max     3.106575   4.106260   2.404785

# %%
largechange.to_csv('highchangeeveningupto2013.csv')

# %%
evening95 = eveningdrop[eveningdrop<eveningdrop.quantile(0.95)]
evening95.describe()
# Out:
#            2010.0      2011.0      2012.0      2013.0
# count  183.000000  183.000000  183.000000  183.000000
# mean    -0.199395   -0.200936   -0.200356   -0.200062
# std      0.386314    0.387012    0.388025    0.393839
# min     -0.337368   -0.343377   -0.346087   -0.350779
# 25%     -0.331500   -0.337413   -0.340235   -0.344933
# 50%     -0.323912   -0.329554   -0.332048   -0.337505
# 75%     -0.274415   -0.278121   -0.279501   -0.279562
# max      2.124684    2.051910    2.075177    2.010116

# %%
eveningdeltas = evening95.pct_change(axis = 1)
eveningdeltas = eveningdeltas.drop(2010.0, axis = 1)
eveningdeltas.dropna()
eveningdeltas.describe(percentiles=[0.05, 0.1, 0.5, 0.85, 0.9, 0.95])
# Out:
#            2011.0      2012.0      2013.0
# count  182.000000  183.000000  183.000000
# mean     0.041227    0.043147    0.017944
# std      0.295282    0.372992    0.212328
# min     -1.122990   -0.435514   -0.601678
# 5%      -0.083775   -0.106947   -0.048101
# 10%     -0.022600   -0.031041   -0.020281
# 50%      0.017459    0.007867    0.014578
# 85%      0.019432    0.010922    0.019581
# 90%      0.020425    0.014587    0.025787
# 95%      0.065983    0.097056    0.061031
# max      3.106575    4.106260    2.404785

# %%
largechange = eveningdeltas[eveningdeltas>=eveningdeltas.quantile(0.90)]
largechange = largechange.dropna(how='all')
largechange.describe()
# Out:
#           2011.0     2012.0     2013.0
# count  19.000000  19.000000  19.000000
# mean    0.432715   0.520529   0.256412
# std     0.778402   1.049174   0.549790
# min     0.020429   0.014690   0.026340
# 25%     0.024309   0.026097   0.042366
# 50%     0.066080   0.100778   0.061107
# 75%     0.445686   0.361217   0.151104
# max     3.106575   4.106260   2.404785

# %%
largechange.to_csv('highchangeeveningupto201390pc.csv')
